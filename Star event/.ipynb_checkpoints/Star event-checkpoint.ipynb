# %% [markdown]
# Jour 2

# %%
text = open("input2.txt","r")
lines = text.readlines()
tableA = {"Y":6,"X":3,"Z":0}
tableA_r = {"X":"Z","Y":"X","Z":"Y"}
tableB = {"Z":6,"Y":3,"X":0}
tableB_r = {"X":"X","Y":"Y","Z":"Z"}
tableC = {"X":6,"Z":3,"Y":0}
tableC_r = {"X":"Y","Y":"Z","Z":"X"}
points = {"X":1,"Y":2,"Z":3}
score = 0

for line in lines:
    letters = line.split()
    match letters[0]:
        case "A":
            letter = tableA_r[letters[1]]
            score += tableA[letter] + points[letter]
        case "B":
            letter = tableB_r[letters[1]]
            score += tableB[letter] + points[letter]
        case "C":
            letter = tableC_r[letters[1]]
            score += tableC[letter] + points[letter]

print(score)
# Out:
# 14979

# %% [markdown]
# Jour 3

# %%
text = open("input3.txt","r")
lines = text.readlines()
score = 0
letters_both = []
for line in lines:
    sac1 = line[:len(line)//2]
    sac2 = line[len(line)//2:]
    found = False
    for letter in sac2:
        if not found and letter in sac1:
            found = True
            letters_both.append(letter)
    
for letter in letters_both:
    if ord(letter) >= 97:
        score += ord(letter) - 96
    else:
        score += ord(letter) - 38

print(score)
# Out:
# 7817

# %%
text = open("input3.txt","r")
lines = text.readlines()
score = 0
letters_badge = []
lines_group = []
found = False

for line in lines:
    if len(lines_group) == 3:
        for letter in lines_group[0]:
            if not found and letter in lines_group[1] and letter in lines_group[2]:
                found = True
                letters_badge.append(letter)
        found = False
        lines_group.clear()
        lines_group.append(line)
    else:
        lines_group.append(line)
        
for letter in lines_group[0]:
    if not found and letter in lines_group[1] and letter in lines_group[2]:
        found = True
        letters_badge.append(letter)
    
for letter in letters_badge:
    if ord(letter) >= 97:
        score += ord(letter) - 96
    else:
        score += ord(letter) - 38

print(score)
# Out:
# 2444

# %% [markdown]
# Jour 4

# %%
text = open("input4.txt","r")
lines = text.readlines()
score = 0

for compteur, line in enumerate(lines):
    elf1, elf2 = line.split(",")
    inter_1 = elf1.split("-")
    inter_2 = elf2.split("-")
    bool1 = (int(inter_1[0]) <= int(inter_2[0])) and (int(inter_1[1]) >= int(inter_2[1]))
    bool2 = (int(inter_1[0]) >= int(inter_2[0])) and (int(inter_1[1]) <= int(inter_2[1]))
    print(compteur+1," : ",(inter_1[1] >= inter_2[1]),inter_1[1],inter_2[1],(91 >= 91))
    print(inter_1[0],inter_2[0],inter_1[1],inter_2[1])
    if bool1 or bool2:
        score += 1

print(score)
# Out:
# 1  :  False 53 82
#  True
# 13 17 53 82
#
# 2  :  False 32 42
#  True
# 32 32 32 42
#
# 3  :  False 85 86
#  True
# 85 8 85 86
#
# 4  :  False 80 91
#  True
# 78 79 80 91
#
# 5  :  True 71 70
#  True
# 60 59 71 70
#
# 6  :  True 92 90
#  True
# 91 4 92 90
#
# 7  :  False 90 90
#  True
# 90 1 90 90
#
# 8  :  False 49 50
#  True
# 35 38 49 50
#
# 9  :  False 51 52
#  True
# 31 31 51 52
#
# 10  :  False 80 81
#  True
# 78 81 80 81
#
# 11  :  False 86 94
#  True
# 85 86 86 94
#
# 12  :  False 95 97
#  True
# 52 96 95 97
#
# 13  :  False 39 40
#  True
# 1 1 39 40
#
# 14  :  True 68 24
#  True
# 8 7 68 24
#
# 15  :  True 89 78
#  True
# 83 58 89 78
#
# 16  :  False 98 99
#  True
# 96 98 98 99
#
# 17  :  False 27 74
#  True
# 26 26 27 74
#
# 18  :  False 43 44
#  True
# 9 8 43 44
#
# 19  :  False 8 89
#  True
# 3 9 8 89
#
# 20  :  True 77 26
#  True
# 3 7 77 26
#
# 21  :  True 88 2
#  True
# 1 2 88 2
#
# 22  :  True 53 52
#  True
# 30 31 53 52
#
# 23  :  False 47 86
#  True
# 3 46 47 86
#
# 24  :  False 78 9
#  True
# 8 7 78 9
#
# 25  :  True 92 52
#  True
# 53 6 92 52
#
# 26  :  False 97 97
#  True
# 84 49 97 97
#
# 27  :  False 67 68
#  True
# 38 38 67 68
#
# 28  :  False 13 95
#  True
# 13 12 13 95
#
# 29  :  False 13 87
#  True
# 7 52 13 87
#
# 30  :  False 18 79
#  True
# 18 17 18 79
#
# 31  :  True 65 64
#  True
# 65 64 65 64
#
# 32  :  True 92 91
#  True
# 12 11 92 91
#
# 33  :  False 67 68
#  True
# 67 2 67 68
#
# 34  :  False 89 92
#  True
# 14 13 89 92
#
# 35  :  True 44 14
#  True
# 13 12 44 14
#
# 36  :  True 42 24
#  True
# 20 21 42 24
#
# 37  :  True 47 11
#  True
# 9 7 47 11
#
# 38  :  True 99 97
#  True
# 99 32 99 97
#
# 39  :  True 37 36
#  True
# 22 21 37 36
#
# 40  :  False 98 99
#  True
# 24 24 98 99
#
# 41  :  False 76 77
#  True
# 62 62 76 77
#
# 42  :  False 50 98
#  True
# 49 49 50 98
#
# 43  :  True 98 79
#  True
# 92 26 98 79
#
# 44  :  False 10 95
#  True
# 5 9 10 95
#
# 45  :  True 92 91
#  True
# 24 24 92 91
#
# 46  :  False 13 30
#  True
# 13 14 13 30
#
# 47  :  False 97 97
#  True
# 56 5 97 97
#
# 48  :  False 33 34
#  True
# 8 9 33 34
#
# 49  :  True 76 75
#  True
# 18 18 76 75
#
# 50  :  True 80 17
#  True
# 16 12 80 17
#
# 51  :  True 99 95
#  True
# 8 8 99 95
#
# 52  :  True 97 96
#  True
# 4 3 97 96
#
# 53  :  False 12 86
#  True
# 11 11 12 86
#
# 54  :  True 90 89
#  True
# 5 1 90 89
#
# 55  :  False 71 84
#  True
# 32 31 71 84
#
# 56  :  True 96 91
#  True
# 12 14 96 91
#
# 57  :  True 9 71
#  True
# 9 12 9 71
#
# 58  :  True 93 92
#  True
# 13 8 93 92
#
# 59  :  False 77 93
#  True
# 4 78 77 93
#
# 60  :  False 6 89
#  True
# 4 5 6 89
#
# 61  :  True 52 51
#  True
# 18 17 52 51
#
# 62  :  True 65 64
#  True
# 35 11 65 64
#
# 63  :  True 77 76
#  True
# 76 1 77 76
#
# 64  :  False 24 43
#  True
# 24 26 24 43
#
# 65  :  True 8 48
#  True
# 4 7 8 48
#
# 66  :  False 85 86
#  True
# 85 5 85 86
#
# 67  :  True 86 85
#  True
# 1 4 86 85
#
# 68  :  False 44 45
#  True
# 10 10 44 45
#
# 69  :  True 91 79
#  True
# 19 36 91 79
#
# 70  :  False 95 98
#  True
# 63 75 95 98
#
# 71  :  False 86 87
#  True
# 59 59 86 87
#
# 72  :  True 91 90
#  True
# 87 42 91 90
#
# 73  :  True 98 96
#  True
# 49 48 98 96
#
# 74  :  True 28 27
#  True
# 2 2 28 27
#
# 75  :  True 91 90
#  True
# 4 4 91 90
#
# 76  :  True 98 91
#  True
# 93 28 98 91
#
# 77  :  True 91 90
#  True
# 5 90 91 90
#
# 78  :  False 77 85
#  True
# 67 82 77 85
#
# 79  :  True 98 94
#  True
# 98 66 98 94
#
# 80  :  False 36 46
#  True
# 19 33 36 46
#
# 81  :  True 54 53
#  True
# 6 6 54 53
#
# 82  :  False 82 90
#  True
# 52 87 82 90
#
# 83  :  True 99 94
#  True
# 94 1 99 94
#
# 84  :  False 2 96
#  True
# 2 1 2 96
#
# 85  :  True 46 45
#  True
# 43 42 46 45
#
# 86  :  False 23 30
#  True
# 20 25 23 30
#
# 87  :  True 93 92
#  True
# 7 6 93 92
#
# 88  :  True 56 19
#  True
# 18 17 56 19
#
# 89  :  False 95 96
#  True
# 40 39 95 96
#
# 90  :  False 90 99
#  True
# 35 91 90 99
#
# 91  :  False 17 19
#  True
# 15 15 17 19
#
# 92  :  False 31 99
#  True
# 29 37 31 99
#
# 93  :  False 91 92
#  True
# 2 6 91 92
#
# 94  :  False 28 7
#  True
# 11 7 28 7
#
# 95  :  True 50 11
#  True
# 10 9 50 11
#
# 96  :  True 89 26
#  True
# 27 10 89 26
#
# 97  :  False 60 61
#  True
# 33 33 60 61
#
# 98  :  True 68 67
#  True
# 66 55 68 67
#
# 99  :  False 11 90
#  True
# 11 10 11 90
#
# 100  :  True 20 11
#  True
# 10 9 20 11
#
# 101  :  False 96 98
#  True
# 73 20 96 98
#
# 102  :  False 85 86
#  True
# 6 6 85 86
#
# 103  :  True 82 8
#  True
# 7 6 82 8
#
# 104  :  False 54 57
#  True
# 37 10 54 57
#
# 105  :  True 87 86
#  True
# 36 35 87 86
#
# 106  :  False 86 93
#  True
# 46 86 86 93
#
# 107  :  False 68 69
#  True
# 4 7 68 69
#
# 108  :  False 26 26
#  True
# 25 20 26 26
#
# 109  :  True 99 89
#  True
# 99 2 99 89
#
# 110  :  False 10 17
#  True
# 1 3 10 17
#
# 111  :  True 92 5
#  True
# 6 5 92 5
#
# 112  :  True 87 30
#  True
# 29 1 87 30
#
# 113  :  False 74 74
#  True
# 7 12 74 74
#
# 114  :  False 36 97
#  True
# 26 25 36 97
#
# 115  :  False 83 84
#  True
# 29 16 83 84
#
# 116  :  False 97 98
#  True
# 13 13 97 98
#
# 117  :  False 72 72
#  True
# 34 35 72 72
#
# 118  :  True 62 61
#  True
# 55 61 62 61
#
# 119  :  False 95 95
#  True
# 24 59 95 95
#
# 120  :  True 38 37
#  True
# 4 4 38 37
#
# 121  :  False 73 77
#  True
# 62 8 73 77
#
# 122  :  True 35 2
#  True
# 5 2 35 2
#
# 123  :  True 79 78
#  True
# 79 4 79 78
#
# 124  :  True 51 50
#  True
# 18 18 51 50
#
# 125  :  False 12 9
#  True
# 10 9 12 9
#
# 126  :  True 83 44
#  True
# 44 6 83 44
#
# 127  :  False 81 98
#  True
# 71 95 81 98
#
# 128  :  True 98 97
#  True
# 36 26 98 97
#
# 129  :  False 74 74
#  True
# 67 19 74 74
#
# 130  :  True 89 80
#  True
# 81 40 89 80
#
# 131  :  False 81 94
#  True
# 26 53 81 94
#
# 132  :  True 64 63
#  True
# 64 26 64 63
#
# 133  :  False 67 75
#  True
# 34 11 67 75
#
# 134  :  False 56 56
#  True
# 13 14 56 56
#
# 135  :  False 55 56
#  True
# 55 44 55 56
#
# 136  :  False 51 97
#  True
# 3 3 51 97
#
# 137  :  True 80 77
#  True
# 76 75 80 77
#
# 138  :  False 66 89
#  True
# 5 77 66 89
#
# 139  :  True 70 49
#  True
# 49 18 70 49
#
# 140  :  True 53 33
#  True
# 32 14 53 33
#
# 141  :  False 30 31
#  True
# 30 30 30 31
#
# 142  :  True 7 47
#  True
# 3 14 7 47
#
# 143  :  False 33 33
#  True
# 33 1 33 33
#
# 144  :  False 9 95
#  True
# 7 11 9 95
#
# 145  :  False 92 92
#  True
# 92 37 92 92
#
# 146  :  False 90 90
#  True
# 40 4 90 90
#
# 147  :  True 79 46
#  True
# 33 7 79 46
#
# 148  :  True 64 49
#  True
# 50 26 64 49
#
# 149  :  False 94 94
#  True
# 3 37 94 94
#
# 150  :  False 68 77
#  True
# 32 68 68 77
#
# 151  :  False 17 6
#  True
# 5 1 17 6
#
# 152  :  True 86 6
#  True
# 6 3 86 6
#
# 153  :  False 46 76
#  True
# 26 21 46 76
#
# 154  :  False 74 75
#  True
# 14 38 74 75
#
# 155  :  True 86 85
#  True
# 3 20 86 85
#
# 156  :  True 70 69
#  True
# 60 60 70 69
#
# 157  :  False 32 33
#  True
# 10 11 32 33
#
# 158  :  False 43 43
#  True
# 43 11 43 43
#
# 159  :  True 96 95
#  True
# 17 9 96 95
#
# 160  :  True 96 95
#  True
# 36 37 96 95
#
# 161  :  False 94 95
#  True
# 11 87 94 95
#
# 162  :  False 94 94
#  True
# 9 8 94 94
#
# 163  :  True 61 60
#  True
# 60 45 61 60
#
# 164  :  False 58 58
#  True
# 25 24 58 58
#
# 165  :  False 81 92
#  True
# 46 45 81 92
#
# 166  :  False 77 80
#  True
# 37 38 77 80
#
# 167  :  False 95 96
#  True
# 95 2 95 96
#
# 168  :  True 71 70
#  True
# 57 56 71 70
#
# 169  :  False 93 94
#  True
# 28 59 93 94
#
# 170  :  False 88 90
#  True
# 16 15 88 90
#
# 171  :  True 38 22
#  True
# 12 12 38 22
#
# 172  :  False 88 99
#  True
# 13 87 88 99
#
# 173  :  True 38 37
#  True
# 7 7 38 37
#
# 174  :  True 70 69
#  True
# 3 4 70 69
#
# 175  :  True 77 76
#  True
# 44 45 77 76
#
# 176  :  False 69 98
#  True
# 4 2 69 98
#
# 177  :  True 79 78
#  True
# 45 44 79 78
#
# 178  :  True 91 33
#  True
# 39 2 91 33
#
# 179  :  True 78 77
#  True
# 33 33 78 77
#
# 180  :  True 91 90
#  True
# 91 16 91 90
#
# 181  :  False 94 97
#  True
# 63 95 94 97
#
# 182  :  False 97 97
#  True
# 1 1 97 97
#
# 183  :  True 38 19
#  True
# 19 3 38 19
#
# 184  :  False 95 96
#  True
# 95 91 95 96
#
# 185  :  False 77 78
#  True
# 53 15 77 78
#
# 186  :  False 53 53
#  True
# 8 7 53 53
#
# 187  :  False 41 42
#  True
# 20 28 41 42
#
# 188  :  False 7 90
#  True
# 5 7 7 90
#
# 189  :  False 86 87
#  True
# 55 85 86 87
#
# 190  :  True 92 80
#  True
# 2 9 92 80
#
# 191  :  False 79 89
#  True
# 17 79 79 89
#
# 192  :  False 77 78
#  True
# 43 44 77 78
#
# 193  :  True 66 60
#  True
# 61 60 66 60
#
# 194  :  False 76 8
#  True
# 8 5 76 8
#
# 195  :  False 83 83
#  True
# 40 39 83 83
#
# 196  :  False 79 80
#  True
# 69 79 79 80
#
# 197  :  False 51 92
#  True
# 51 50 51 92
#
# 198  :  False 99 99
#  True
# 29 18 99 99
#
# 199  :  True 75 18
#  True
# 18 17 75 18
#
# 200  :  False 39 59
#  True
# 17 8 39 59
#
# 201  :  False 35 79
#  True
# 9 34 35 79
#
# 202  :  False 52 53
#  True
# 8 7 52 53
#
# 203  :  True 95 94
#  True
# 51 75 95 94
#
# 204  :  False 94 94
#  True
# 94 1 94 94
#
# 205  :  False 55 56
#  True
# 37 32 55 56
#
# 206  :  True 84 6
#  True
# 6 1 84 6
#
# 207  :  False 19 40
#  True
# 19 18 19 40
#
# 208  :  True 97 95
#  True
# 95 28 97 95
#
# 209  :  True 99 92
#  True
# 89 82 99 92
#
# 210  :  False 47 47
#  True
# 11 46 47 47
#
# 211  :  False 98 99
#  True
# 4 4 98 99
#
# 212  :  False 16 94
#  True
# 12 23 16 94
#
# 213  :  True 50 49
#  True
# 18 17 50 49
#
# 214  :  True 72 57
#  True
# 37 35 72 57
#
# 215  :  True 77 24
#  True
# 23 22 77 24
#
# 216  :  True 65 54
#  True
# 54 6 65 54
#
# 217  :  True 74 73
#  True
# 61 39 74 73
#
# 218  :  True 94 90
#  True
# 83 52 94 90
#
# 219  :  True 99 14
#  True
# 13 2 99 14
#
# 220  :  False 98 99
#  True
# 10 11 98 99
#
# 221  :  False 98 99
#  True
# 30 29 98 99
#
# 222  :  False 90 90
#  True
# 38 37 90 90
#
# 223  :  False 66 68
#  True
# 63 64 66 68
#
# 224  :  False 93 95
#  True
# 49 49 93 95
#
# 225  :  False 88 88
#  True
# 84 79 88 88
#
# 226  :  False 35 83
#  True
# 11 35 35 83
#
# 227  :  False 59 59
#  True
# 2 3 59 59
#
# 228  :  False 64 64
#  True
# 42 57 64 64
#
# 229  :  False 62 88
#  True
# 14 15 62 88
#
# 230  :  False 54 71
#  True
# 52 53 54 71
#
# 231  :  False 66 67
#  True
# 37 38 66 67
#
# 232  :  True 96 92
#  True
# 20 21 96 92
#
# 233  :  True 82 6
#  True
# 5 4 82 6
#
# 234  :  False 52 52
#  True
# 13 13 52 52
#
# 235  :  True 69 21
#  True
# 10 4 69 21
#
# 236  :  False 69 98
#  True
# 5 26 69 98
#
# 237  :  True 57 42
#  True
# 41 40 57 42
#
# 238  :  True 94 93
#  True
# 8 9 94 93
#
# 239  :  False 27 61
#  True
# 6 26 27 61
#
# 240  :  False 65 66
#  True
# 27 27 65 66
#
# 241  :  True 98 97
#  True
# 97 1 98 97
#
# 242  :  False 85 86
#  True
# 46 45 85 86
#
# 243  :  True 48 43
#  True
# 43 38 48 43
#
# 244  :  True 49 48
#  True
# 5 48 49 48
#
# 245  :  True 59 58
#  True
# 14 12 59 58
#
# 246  :  True 97 96
#  True
# 30 7 97 96
#
# 247  :  True 70 69
#  True
# 62 64 70 69
#
# 248  :  True 79 78
#  True
# 31 12 79 78
#
# 249  :  True 18 17
#  True
# 10 9 18 17
#
# 250  :  False 76 76
#  True
# 74 72 76 76
#
# 251  :  False 69 70
#  True
# 29 29 69 70
#
# 252  :  False 93 95
#  True
# 15 93 93 95
#
# 253  :  False 68 73
#  True
# 66 67 68 73
#
# 254  :  True 89 2
#  True
# 2 1 89 2
#
# 255  :  False 95 96
#  True
# 2 9 95 96
#
# 256  :  True 89 45
#  True
# 4 6 89 45
#
# 257  :  False 98 99
#  True
# 98 28 98 99
#
# 258  :  False 77 77
#  True
# 16 4 77 77
#
# 259  :  False 86 87
#  True
# 16 87 86 87
#
# 260  :  False 17 83
#  True
# 17 18 17 83
#
# 261  :  True 82 81
#  True
# 18 29 82 81
#
# 262  :  True 99 98
#  True
# 21 7 99 98
#
# 263  :  False 85 85
#  True
# 36 1 85 85
#
# 264  :  False 70 90
#  True
# 9 70 70 90
#
# 265  :  True 95 94
#  True
# 38 60 95 94
#
# 266  :  False 94 95
#  True
# 94 24 94 95
#
# 267  :  False 63 63
#  True
# 4 3 63 63
#
# 268  :  False 72 88
#  True
# 40 73 72 88
#
# 269  :  False 4 99
#  True
# 3 3 4 99
#
# 270  :  False 27 93
#  True
# 1 3 27 93
#
# 271  :  False 26 27
#  True
# 15 16 26 27
#
# 272  :  True 89 34
#  True
# 10 20 89 34
#
# 273  :  False 18 39
#  True
# 16 6 18 39
#
# 274  :  True 48 34
#  True
# 34 28 48 34
#
# 275  :  True 83 6
#  True
# 5 6 83 6
#
# 276  :  False 49 50
#  True
# 37 38 49 50
#
# 277  :  True 86 38
#  True
# 39 9 86 38
#
# 278  :  False 74 75
#  True
# 12 74 74 75
#
# 279  :  False 80 81
#  True
# 16 15 80 81
#
# 280  :  False 67 85
#  True
# 26 24 67 85
#
# 281  :  True 7 19
#  True
# 5 12 7 19
#
# 282  :  False 68 69
#  True
# 40 69 68 69
#
# 283  :  False 79 95
#  True
# 17 80 79 95
#
# 284  :  True 63 18
#  True
# 17 16 63 18
#
# 285  :  False 72 75
#  True
# 69 16 72 75
#
# 286  :  False 24 89
#  True
# 15 48 24 89
#
# 287  :  False 12 96
#  True
# 12 13 12 96
#
# 288  :  False 4 89
#  True
# 4 6 4 89
#
# 289  :  True 84 39
#  True
# 79 5 84 39
#
# 290  :  False 25 61
#  True
# 23 24 25 61
#
# 291  :  True 97 96
#  True
# 26 6 97 96
#
# 292  :  False 97 97
#  True
# 4 5 97 97
#
# 293  :  False 91 91
#  True
# 55 56 91 91
#
# 294  :  False 80 81
#  True
# 25 80 80 81
#
# 295  :  True 76 75
#  True
# 52 53 76 75
#
# 296  :  False 61 61
#  True
# 45 44 61 61
#
# 297  :  False 81 82
#  True
# 65 64 81 82
#
# 298  :  True 74 64
#  True
# 65 3 74 64
#
# 299  :  True 73 72
#  True
# 4 72 73 72
#
# 300  :  False 54 57
#  True
# 54 53 54 57
#
# 301  :  True 51 50
#  True
# 51 29 51 50
#
# 302  :  False 14 36
#  True
# 1 3 14 36
#
# 303  :  True 95 92
#  True
# 93 57 95 92
#
# 304  :  True 86 85
#  True
# 85 6 86 85
#
# 305  :  True 98 15
#  True
# 3 3 98 15
#
# 306  :  False 21 54
#  True
# 21 20 21 54
#
# 307  :  False 72 73
#  True
# 18 19 72 73
#
# 308  :  False 49 53
#  True
# 27 47 49 53
#
# 309  :  False 77 78
#  True
# 20 21 77 78
#
# 310  :  False 76 76
#  True
# 52 38 76 76
#
# 311  :  False 87 87
#  True
# 82 14 87 87
#
# 312  :  True 79 4
#  True
# 3 1 79 4
#
# 313  :  True 97 1
#  True
# 1 1 97 1
#
# 314  :  False 40 91
#  True
# 39 40 40 91
#
# 315  :  True 11 10
#  True
# 6 5 11 10
#
# 316  :  True 98 6
#  True
# 5 4 98 6
#
# 317  :  False 36 37
#  True
# 36 9 36 37
#
# 318  :  False 69 7
#  True
# 6 7 69 7
#
# 319  :  False 93 95
#  True
# 77 76 93 95
#
# 320  :  True 94 93
#  True
# 41 26 94 93
#
# 321  :  True 81 70
#  True
# 70 7 81 70
#
# 322  :  False 72 72
#  True
# 1 71 72 72
#
# 323  :  False 90 98
#  True
# 30 29 90 98
#
# 324  :  False 76 76
#  True
# 68 12 76 76
#
# 325  :  True 42 19
#  True
# 28 15 42 19
#
# 326  :  True 96 77
#  True
# 76 39 96 77
#
# 327  :  False 32 90
#  True
# 30 46 32 90
#
# 328  :  True 98 92
#  True
# 83 83 98 92
#
# 329  :  False 98 98
#  True
# 1 9 98 98
#
# 330  :  True 93 92
#  True
# 17 16 93 92
#
# 331  :  True 89 8
#  True
# 17 3 89 8
#
# 332  :  False 67 67
#  True
# 61 62 67 67
#
# 333  :  True 63 20
#  True
# 19 18 63 20
#
# 334  :  False 53 98
#  True
# 51 52 53 98
#
# 335  :  False 21 58
#  True
# 20 20 21 58
#
# 336  :  False 86 87
#  True
# 5 6 86 87
#
# 337  :  True 85 84
#  True
# 23 24 85 84
#
# 338  :  True 54 53
#  True
# 34 22 54 53
#
# 339  :  False 67 68
#  True
# 20 20 67 68
#
# 340  :  True 88 26
#  True
# 26 26 88 26
#
# 341  :  False 94 94
#  True
# 26 27 94 94
#
# 342  :  False 29 84
#  True
# 27 29 29 84
#
# 343  :  True 73 42
#  True
# 42 2 73 42
#
# 344  :  True 72 71
#  True
# 68 56 72 71
#
# 345  :  True 85 84
#  True
# 13 16 85 84
#
# 346  :  False 87 95
#  True
# 54 88 87 95
#
# 347  :  False 29 35
#  True
# 26 32 29 35
#
# 348  :  False 21 45
#  True
# 2 20 21 45
#
# 349  :  False 18 48
#  True
# 18 19 18 48
#
# 350  :  True 98 88
#  True
# 91 31 98 88
#
# 351  :  False 59 60
#  True
# 5 41 59 60
#
# 352  :  True 96 94
#  True
# 94 70 96 94
#
# 353  :  False 85 89
#  True
# 8 86 85 89
#
# 354  :  False 97 99
#  True
# 3 98 97 99
#
# 355  :  False 90 92
#  True
# 89 16 90 92
#
# 356  :  False 44 74
#  True
# 13 43 44 74
#
# 357  :  False 87 99
#  True
# 6 25 87 99
#
# 358  :  False 5 53
#  True
# 5 6 5 53
#
# 359  :  True 85 84
#  True
# 3 1 85 84
#
# 360  :  True 94 87
#  True
# 25 35 94 87
#
# 361  :  True 95 64
#  True
# 17 17 95 64
#
# 362  :  False 85 85
#  True
# 12 13 85 85
#
# 363  :  False 4 75
#  True
# 2 4 4 75
#
# 364  :  True 25 24
#  True
# 7 8 25 24
#
# 365  :  False 96 96
#  True
# 47 24 96 96
#
# 366  :  True 96 94
#  True
# 95 94 96 94
#
# 367  :  True 94 93
#  True
# 94 93 94 93
#
# 368  :  False 77 90
#  True
# 22 3 77 90
#
# 369  :  False 77 83
#  True
# 17 78 77 83
#
# 370  :  False 42 75
#  True
# 35 48 42 75
#
# 371  :  False 12 97
#  True
# 12 13 12 97
#
# 372  :  False 19 77
#  True
# 13 18 19 77
#
# 373  :  False 83 83
#  True
# 32 26 83 83
#
# 374  :  True 78 32
#  True
# 31 3 78 32
#
# 375  :  False 17 95
#  True
# 3 17 17 95
#
# 376  :  False 61 61
#  True
# 45 44 61 61
#
# 377  :  True 81 80
#  True
# 73 13 81 80
#
# 378  :  True 99 93
#  True
# 2 6 99 93
#
# 379  :  True 88 74
#  True
# 80 33 88 74
#
# 380  :  True 86 44
#  True
# 45 3 86 44
#
# 381  :  False 75 93
#  True
# 39 39 75 93
#
# 382  :  False 96 96
#  True
# 2 95 96 96
#
# 383  :  False 64 65
#  True
# 10 9 64 65
#
# 384  :  True 76 5
#  True
# 4 5 76 5
#
# 385  :  True 96 73
#  True
# 72 72 96 73
#
# 386  :  True 85 79
#  True
# 78 77 85 79
#
# 387  :  False 94 98
#  True
# 20 19 94 98
#
# 388  :  True 87 15
#  True
# 14 3 87 15
#
# 389  :  False 35 53
#  True
# 21 35 35 53
#
# 390  :  False 87 93
#  True
# 2 88 87 93
#
# 391  :  True 90 87
#  True
# 15 15 90 87
#
# 392  :  False 99 99
#  True
# 3 2 99 99
#
# 393  :  False 95 96
#  True
# 9 9 95 96
#
# 394  :  False 89 90
#  True
# 5 1 89 90
#
# 395  :  False 73 74
#  True
# 6 3 73 74
#
# 396  :  True 76 51
#  True
# 52 6 76 51
#
# 397  :  False 52 69
#  True
# 5 66 52 69
#
# 398  :  False 19 36
#  True
# 17 18 19 36
#
# 399  :  False 43 9
#  True
# 8 2 43 9
#
# 400  :  False 72 73
#  True
# 56 63 72 73
#
# 401  :  False 91 92
#  True
# 73 66 91 92
#
# 402  :  False 89 89
#  True
# 4 5 89 89
#
# 403  :  True 99 93
#  True
# 95 9 99 93
#
# 404  :  False 98 99
#  True
# 91 92 98 99
#
# 405  :  True 78 7
#  True
# 18 6 78 7
#
# 406  :  False 71 94
#  True
# 11 71 71 94
#
# 407  :  True 99 97
#  True
# 1 3 99 97
#
# 408  :  True 90 8
#  True
# 7 1 90 8
#
# 409  :  False 87 88
#  True
# 5 5 87 88
#
# 410  :  False 48 97
#  True
# 46 47 48 97
#
# 411  :  True 92 91
#  True
# 3 7 92 91
# 412  :  False 33 73
#  True
# 33 32 33 73
#
# 413  :  False 95 98
#  True
# 39 38 95 98
#
# 414  :  True 82 81
#  True
# 35 36 82 81
#
# 415  :  False 90 95
#  True
# 41 86 90 95
#
# 416  :  True 45 44
#  True
# 21 44 45 44
#
# 417  :  True 5 49
#  True
# 5 6 5 49
#
# 418  :  True 67 66
#  True
# 49 50 67 66
#
# 419  :  False 76 77
#  True
# 8 8 76 77
#
# 420  :  False 17 73
#  True
# 15 29 17 73
#
# 421  :  True 95 34
#  True
# 35 20 95 34
#
# 422  :  False 64 64
#  True
# 29 30 64 64
#
# 423  :  False 45 46
#  True
# 11 11 45 46
#
# 424  :  True 87 13
#  True
# 14 4 87 13
#
# 425  :  True 69 37
#  True
# 38 37 69 37
#
# 426  :  False 76 9
#  True
# 11 6 76 9
#
# 427  :  True 98 97
#  True
# 70 62 98 97
#
# 428  :  True 99 18
#  True
# 17 16 99 18
#
# 429  :  True 82 81
#  True
# 2 5 82 81
#
# 430  :  False 93 94
#  True
# 15 4 93 94
#
# 431  :  False 57 57
#  True
# 56 56 57 57
#
# 432  :  False 6 88
#  True
# 1 6 6 88
#
# 433  :  True 93 49
#  True
# 48 48 93 49
#
# 434  :  True 75 74
#  True
# 7 39 75 74
#
# 435  :  False 3 90
#  True
# 1 2 3 90
#
# 436  :  False 31 31
#  True
# 27 28 31 31
#
# 437  :  False 10 63
#  True
# 10 9 10 63
#
# 438  :  False 64 79
#  True
# 11 65 64 79
#
# 439  :  False 57 69
#  True
# 57 56 57 69
#
# 440  :  False 50 88
#  True
# 50 49 50 88
#
# 441  :  False 43 44
#  True
# 43 2 43 44
#
# 442  :  False 59 59
#  True
# 15 11 59 59
#
# 443  :  True 44 28
#  True
# 28 7 44 28
#
# 444  :  False 39 42
#  True
# 5 37 39 42
#
# 445  :  False 95 95
#  True
# 88 95 95 95
#
# 446  :  False 63 63
#  True
# 2 63 63 63
#
# 447  :  False 91 98
#  True
# 5 14 91 98
#
# 448  :  False 89 98
#  True
# 7 6 89 98
#
# 449  :  False 36 56
#  True
# 16 36 36 56
#
# 450  :  False 80 83
#  True
# 40 81 80 83
#
# 451  :  True 99 98
#  True
# 4 2 99 98
#
# 452  :  False 70 71
#  True
# 70 2 70 71
#
# 453  :  False 45 46
#  True
# 6 7 45 46
#
# 454  :  True 97 96
#  True
# 9 10 97 96
#
# 455  :  True 79 34
#  True
# 34 33 79 34
#
# 456  :  False 55 55
#  True
# 51 50 55 55
#
# 457  :  False 72 79
#  True
# 27 58 72 79
#
# 458  :  True 65 64
#  True
# 9 8 65 64
#
# 459  :  False 5 99
#  True
# 3 4 5 99
#
# 460  :  True 43 16
#  True
# 17 11 43 16
#
# 461  :  True 29 28
#  True
# 9 10 29 28
#
# 462  :  True 91 90
#  True
# 23 24 91 90
#
# 463  :  True 80 14
#  True
# 13 10 80 14
#
# 464  :  False 85 86
#  True
# 47 86 85 86
#
# 465  :  False 25 8
#  True
# 9 4 25 8
#
# 466  :  False 92 92
#  True
# 43 43 92 92
#
# 467  :  True 90 89
#  True
# 89 76 90 89
#
# 468  :  True 88 31
#  True
# 32 4 88 31
#
# 469  :  True 52 51
#  True
# 33 32 52 51
#
# 470  :  False 97 99
#  True
# 3 1 97 99
#
# 471  :  True 91 51
#  True
# 39 40 91 51
#
# 472  :  False 92 92
#  True
# 19 22 92 92
#
# 473  :  False 89 92
#  True
# 4 23 89 92
#
# 474  :  False 6 66
#  True
# 5 6 6 66
#
# 475  :  True 99 78
#  True
# 6 7 99 78
#
# 476  :  False 93 93
#  True
# 8 92 93 93
#
# 477  :  False 95 97
#  True
# 5 58 95 97
#
# 478  :  False 96 99
#  True
# 2 99 96 99
#
# 479  :  True 39 35
#  True
# 34 35 39 35
#
# 480  :  False 92 93
#  True
# 92 3 92 93
#
# 481  :  True 54 53
#  True
# 38 11 54 53
#
# 482  :  False 59 87
#  True
# 45 59 59 87
#
# 483  :  True 78 54
#  True
# 55 54 78 54
#
# 484  :  False 66 66
#  True
# 42 42 66 66
#
# 485  :  False 91 92
#  True
# 19 22 91 92
#
# 486  :  False 46 91
#  True
# 39 38 46 91
#
# 487  :  True 89 41
#  True
# 42 41 89 41
#
# 488  :  True 66 65
#  True
# 33 34 66 65
#
# 489  :  True 71 70
#  True
# 7 6 71 70
#
# 490  :  True 80 61
#  True
# 7 30 80 61
#
# 491  :  True 91 90
#  True
# 58 57 91 90
#
# 492  :  False 95 95
#  True
# 30 88 95 95
#
# 493  :  False 97 99
#  True
# 4 96 97 99
#
# 494  :  True 99 95
#  True
# 12 12 99 95
#
# 495  :  False 41 50
#  True
# 39 40 41 50
#
# 496  :  False 87 87
#  True
# 34 35 87 87
#
# 497  :  True 86 12
#  True
# 14 2 86 12
#
# 498  :  True 87 86
#  True
# 14 15 87 86
#
# 499  :  True 97 96
#  True
# 7 96 97 96
#
# 500  :  False 36 46
#  True
# 7 31 36 46
#
# 501  :  True 75 49
#  True
# 6 7 75 49
#
# 502  :  False 29 81
#  True
# 29 28 29 81
#
# 503  :  False 67 68
#  True
# 58 68 67 68
#
# 504  :  True 97 91
#  True
# 18 18 97 91
#
# 505  :  True 31 30
#  True
# 17 27 31 30
#
# 506  :  False 46 96
#  True
# 39 51 46 96
#
# 507  :  True 89 69
#  True
# 68 69 89 69
#
# 508  :  False 57 57
#  True
# 15 15 57 57
#
# 509  :  False 24 77
#  True
# 24 16 24 77
#
# 510  :  False 92 93
#  True
# 40 91 92 93
#
# 511  :  False 61 76
#  True
# 43 41 61 76
#
# 512  :  True 49 48
#  True
# 49 42 49 48
#
# 513  :  True 76 75
#  True
# 34 15 76 75
#
# 514  :  False 73 74
#  True
# 2 74 73 74
#
# 515  :  True 98 97
#  True
# 16 16 98 97
#
# 516  :  False 80 80
#  True
# 7 6 80 80
#
# 517  :  True 66 65
#  True
# 23 24 66 65
#
# 518  :  False 81 82
#  True
# 39 40 81 82
#
# 519  :  True 99 37
#  True
# 74 33 99 37
#
# 520  :  False 93 93
#  True
# 81 64 93 93
#
# 521  :  False 86 95
#  True
# 19 86 86 95
#
# 522  :  False 97 98
#  True
# 97 9 97 98
#
# 523  :  False 70 71
#  True
# 45 62 70 71
#
# 524  :  True 67 53
#  True
# 54 20 67 53
#
# 525  :  False 85 85
#  True
# 85 18 85 85
#
# 526  :  True 79 76
#  True
# 11 28 79 76
#
# 527  :  True 96 40
#  True
# 40 12 96 40
#
# 528  :  False 79 80
#  True
# 19 35 79 80
#
# 529  :  False 91 92
#  True
# 3 1 91 92
#
# 530  :  True 90 89
#  True
# 5 5 90 89
#
# 531  :  True 93 92
#  True
# 42 43 93 92
#
# 532  :  True 70 38
#  True
# 40 34 70 38
#
# 533  :  True 43 12
#  True
# 12 11 43 12
#
# 534  :  True 22 21
#  True
# 22 3 22 21
#
# 535  :  True 90 65
#  True
# 53 7 90 65
#
# 536  :  True 90 15
#  True
# 22 11 90 15
#
# 537  :  False 24 36
#  True
# 24 24 24 36
#
# 538  :  False 3 55
#  True
# 3 5 3 55
#
# 539  :  True 54 53
#  True
# 53 53 54 53
#
# 540  :  False 53 54
#  True
# 53 26 53 54
#
# 541  :  False 9 97
#  True
# 3 9 9 97
#
# 542  :  False 58 59
#  True
# 43 58 58 59
#
# 543  :  False 64 64
#  True
# 31 17 64 64
#
# 544  :  True 36 35
#  True
# 34 35 36 35
#
# 545  :  False 11 48
#  True
# 4 10 11 48
#
# 546  :  False 39 40
#  True
# 12 15 39 40
#
# 547  :  False 44 92
#  True
# 44 43 44 92
#
# 548  :  False 68 68
#  True
# 9 68 68 68
#
# 549  :  True 95 81
#  True
# 20 20 95 81
#
# 550  :  False 27 62
#  True
# 6 45 27 62
#
# 551  :  False 91 91
#  True
# 7 7 91 91
#
# 552  :  False 3 88
#  True
# 2 5 3 88
#
# 553  :  True 77 61
#  True
# 11 22 77 61
#
# 554  :  True 95 77
#  True
# 8 30 95 77
#
# 555  :  False 97 97
#  True
# 85 86 97 97
#
# 556  :  True 60 18
#  True
# 3 8 60 18
#
# 557  :  True 70 69
#  True
# 14 13 70 69
#
# 558  :  False 81 82
#  True
# 34 61 81 82
#
# 559  :  False 82 82
#  True
# 42 43 82 82
#
# 560  :  True 99 10
#  True
# 9 10 99 10
#
# 561  :  True 75 53
#  True
# 2 19 75 53
#
# 562  :  False 77 86
#  True
# 26 69 77 86
#
# 563  :  True 97 81
#  True
# 82 27 97 81
#
# 564  :  False 92 93
#  True
# 17 9 92 93
#
# 565  :  True 6 5
#  True
# 5 5 6 5
#
# 566  :  False 46 47
#  True
# 46 45 46 47
#
# 567  :  False 67 68
#  True
# 21 21 67 68
#
# 568  :  True 95 36
#  True
# 36 17 95 36
#
# 569  :  False 88 89
#  True
# 41 41 88 89
#
# 570  :  True 81 80
#  True
# 6 11 81 80
#
# 571  :  False 45 46
#  True
# 26 45 45 46
#
# 572  :  True 75 4
#  True
# 4 2 75 4
#
# 573  :  True 36 35
#  True
# 27 24 36 35
#
# 574  :  False 64 97
#  True
# 49 50 64 97
#
# 575  :  True 86 85
#  True
# 86 40 86 85
#
# 576  :  False 5 92
#  True
# 5 5 5 92
#
# 577  :  False 82 82
#  True
# 81 6 82 82
#
# 578  :  False 92 93
#  True
# 14 93 92 93
#
# 579  :  False 36 65
#  True
# 28 35 36 65
#
# 580  :  False 17 27
#  True
# 12 18 17 27
#
# 581  :  False 68 68
#  True
# 28 6 68 68
#
# 582  :  True 93 48
#  True
# 47 48 93 48
#
# 583  :  True 99 97
#  True
# 20 11 99 97
#
# 584  :  True 75 18
#  True
# 32 9 75 18
#
# 585  :  False 96 96
#  True
# 53 96 96 96
#
# 586  :  True 64 63
#  True
# 33 32 64 63
#
# 587  :  True 83 78
#  True
# 79 3 83 78
#
# 588  :  False 46 79
#  True
# 38 47 46 79
#
# 589  :  False 88 98
#  True
# 3 4 88 98
#
# 590  :  True 97 96
#  True
# 6 96 97 96
#
# 591  :  False 68 69
#  True
# 68 42 68 69
#
# 592  :  True 99 23
#  True
# 24 23 99 23
#
# 593  :  False 98 99
#  True
# 27 65 98 99
#
# 594  :  True 94 5
#  True
# 9 5 94 5
#
# 595  :  True 30 23
#  True
# 22 23 30 23
#
# 596  :  True 72 71
#  True
# 71 23 72 71
#
# 597  :  True 97 96
#  True
# 2 2 97 96
#
# 598  :  True 58 57
#  True
# 6 7 58 57
#
# 599  :  True 88 74
#  True
# 44 45 88 74
#
# 600  :  False 97 99
#  True
# 2 98 97 99
#
# 601  :  True 30 27
#  True
# 27 9 30 27
#
# 602  :  False 89 89
#  True
# 10 48 89 89
#
# 603  :  True 99 88
#  True
# 19 18 99 88
#
# 604  :  True 95 78
#  True
# 95 15 95 78
#
# 605  :  False 30 31
#  True
# 10 10 30 31
#
# 606  :  True 97 79
#  True
# 10 11 97 79
#
# 607  :  False 97 98
#  True
# 5 1 97 98
#
# 608  :  False 99 99
#  True
# 17 1 99 99
#
# 609  :  False 29 95
#  True
# 27 28 29 95
#
# 610  :  False 90 90
#  True
# 90 33 90 90
#
# 611  :  True 65 64
#  True
# 64 3 65 64
#
# 612  :  True 98 97
#  True
# 34 35 98 97
#
# 613  :  False 62 63
#  True
# 23 22 62 63
#
# 614  :  False 85 85
#  True
# 76 85 85 85
#
# 615  :  False 97 98
#  True
# 56 57 97 98
#
# 616  :  False 43 43
#  True
# 43 43 43 43
#
# 617  :  True 83 18
#  True
# 17 16 83 18
#
# 618  :  False 15 15
#  True
# 4 6 15 15
#
# 619  :  False 70 70
#  True
# 18 66 70 70
#
# 620  :  True 63 62
#  True
# 62 9 63 62
#
# 621  :  True 85 80
#  True
# 81 32 85 80
#
# 622  :  True 95 90
#  True
# 35 24 95 90
#
# 623  :  False 62 62
#  True
# 6 7 62 62
#
# 624  :  False 19 29
#  True
# 17 18 19 29
#
# 625  :  True 38 37
#  True
# 24 37 38 37
#
# 626  :  False 42 43
#  True
# 2 2 42 43
#
# 627  :  True 50 12
#  True
# 11 10 50 12
#
# 628  :  False 50 51
#  True
# 20 19 50 51
#
# 629  :  False 22 22
#  True
# 22 2 22 22
#
# 630  :  True 54 53
#  True
# 54 8 54 53
#
# 631  :  True 47 46
#  True
# 27 46 47 46
#
# 632  :  True 97 6
#  True
# 11 5 97 6
#
# 633  :  False 99 99
#  True
# 47 1 99 99
#
# 634  :  True 46 45
#  True
# 31 32 46 45
#
# 635  :  True 56 39
#  True
# 8 2 56 39
#
# 636  :  False 95 96
#  True
# 57 10 95 96
#
# 637  :  False 17 75
#  True
# 17 25 17 75
#
# 638  :  True 46 45
#  True
# 44 10 46 45
#
# 639  :  True 33 32
#  True
# 30 29 33 32
#
# 640  :  False 94 95
#  True
# 1 24 94 95
#
# 641  :  False 32 32
#  True
# 31 8 32 32
#
# 642  :  False 21 49
#  True
# 19 20 21 49
#
# 643  :  False 34 35
#  True
# 34 19 34 35
#
# 644  :  False 79 96
#  True
# 33 86 79 96
#
# 645  :  True 98 97
#  True
# 12 12 98 97
#
# 646  :  False 35 36
#  True
# 27 26 35 36
#
# 647  :  False 89 90
#  True
# 37 90 89 90
#
# 648  :  False 5 81
#  True
# 2 4 5 81
#
# 649  :  False 38 39
#  True
# 29 38 38 39
#
# 650  :  True 88 82
#  True
# 3 58 88 82
#
# 651  :  True 8 65
#  True
# 5 7 8 65
#
# 652  :  False 14 73
#  True
# 6 13 14 73
#
# 653  :  False 98 99
#  True
# 57 90 98 99
#
# 654  :  False 53 54
#  True
# 29 30 53 54
#
# 655  :  True 78 60
#  True
# 1 59 78 60
#
# 656  :  False 34 35
#  True
# 34 24 34 35
#
# 657  :  True 12 11
#  True
# 4 11 12 11
#
# 658  :  True 84 83
#  True
# 41 9 84 83
#
# 659  :  True 88 6
#  True
# 5 6 88 6
#
# 660  :  True 78 75
#  True
# 1 8 78 75
#
# 661  :  False 80 81
#  True
# 80 19 80 81
#
# 662  :  True 97 96
#  True
# 95 72 97 96
#
# 663  :  True 85 84
#  True
# 13 84 85 84
#
# 664  :  True 81 32
#  True
# 31 28 81 32
#
# 665  :  True 58 45
#  True
# 53 37 58 45
#
# 666  :  False 69 82
#  True
# 13 62 69 82
#
# 667  :  False 69 69
#  True
# 11 10 69 69
#
# 668  :  False 46 74
#  True
# 46 45 46 74
#
# 669  :  False 93 98
#  True
# 60 77 93 98
#
# 670  :  False 58 59
#  True
# 14 14 58 59
#
# 671  :  True 73 72
#  True
# 73 11 73 72
#
# 672  :  False 91 91
#  True
# 3 32 91 91
#
# 673  :  False 6 87
#  True
# 4 5 6 87
#
# 674  :  True 85 78
#  True
# 11 16 85 78
#
# 675  :  True 99 97
#  True
# 2 89 99 97
#
# 676  :  True 88 87
#  True
# 21 20 88 87
#
# 677  :  True 52 51
#  True
# 4 51 52 51
#
# 678  :  True 22 21
#  True
# 22 1 22 21
#
# 679  :  False 76 94
#  True
# 21 8 76 94
#
# 680  :  True 6 40
#  True
# 4 5 6 40
#
# 681  :  True 97 93
#  True
# 97 5 97 93
#
# 682  :  True 85 23
#  True
# 22 11 85 23
#
# 683  :  True 74 5
#  True
# 6 5 74 5
#
# 684  :  False 91 92
#  True
# 67 66 91 92
#
# 685  :  True 99 98
#  True
# 24 16 99 98
#
# 686  :  True 58 1
#  True
# 2 1 58 1
#
# 687  :  False 52 52
#  True
# 21 20 52 52
#
# 688  :  False 82 96
#  True
# 71 76 82 96
#
# 689  :  True 65 64
#  True
# 5 5 65 64
#
# 690  :  False 6 70
#  True
# 4 9 6 70
#
# 691  :  False 75 88
#  True
# 73 68 75 88
#
# 692  :  True 52 40
#  True
# 39 38 52 40
#
# 693  :  True 32 31
#  True
# 29 29 32 31
#
# 694  :  False 65 66
#  True
# 65 37 65 66
#
# 695  :  True 69 68
#  True
# 3 2 69 68
#
# 696  :  True 97 85
#  True
# 36 36 97 85
#
# 697  :  False 68 69
#  True
# 52 15 68 69
#
# 698  :  False 42 43
#  True
# 3 42 42 43
#
# 699  :  False 25 58
#  True
# 19 25 25 58
#
# 700  :  True 28 27
#  True
# 9 8 28 27
#
# 701  :  False 99 99
#  True
# 23 24 99 99
#
# 702  :  True 98 95
#  True
# 21 22 98 95
#
# 703  :  False 12 13
#  True
# 6 12 12 13
#
# 704  :  False 93 99
#  True
# 42 41 93 99
#
# 705  :  False 83 84
#  True
# 57 58 83 84
#
# 706  :  False 91 94
#  True
# 91 90 91 94
#
# 707  :  False 72 88
#  True
# 71 71 72 88
#
# 708  :  True 97 3
#  True
# 2 1 97 3
#
# 709  :  False 12 49
#  True
# 9 11 12 49
#
# 710  :  False 81 82
#  True
# 75 38 81 82
#
# 711  :  True 75 52
#  True
# 38 16 75 52
#
# 712  :  False 18 91
#  True
# 16 17 18 91
#
# 713  :  True 72 71
#  True
# 29 30 72 71
#
# 714  :  True 83 82
#  True
# 83 45 83 82
#
# 715  :  False 56 57
#  True
# 17 19 56 57
#
# 716  :  False 52 78
#  True
# 50 51 52 78
#
# 717  :  True 67 66
#  True
# 17 66 67 66
#
# 718  :  True 81 80
#  True
# 3 3 81 80
#
# 719  :  False 48 65
#  True
# 20 49 48 65
#
# 720  :  True 51 18
#  True
# 17 10 51 18
#
# 721  :  True 9 10
#  True
# 1 2 9 10
#
# 722  :  True 49 48
#  True
# 49 46 49 48
#
# 723  :  False 96 96
#  True
# 95 55 96 96
#
# 724  :  True 89 74
#  True
# 27 28 89 74
#
# 725  :  False 76 82
#  True
# 47 28 76 82
#
# 726  :  False 95 96
#  True
# 9 10 95 96
#
# 727  :  False 88 88
#  True
# 87 5 88 88
#
# 728  :  True 74 47
#  True
# 27 28 74 47
#
# 729  :  True 93 92
#  True
# 74 46 93 92
#
# 730  :  False 95 98
#  True
# 3 98 95 98
#
# 731  :  False 50 50
#  True
# 49 26 50 50
#
# 732  :  False 79 79
#  True
# 28 27 79 79
#
# 733  :  False 53 93
#  True
# 15 14 53 93
#
# 734  :  True 36 18
#  True
# 17 17 36 18
#
# 735  :  False 72 75
#  True
# 7 64 72 75
#
# 736  :  False 96 99
#  True
# 7 32 96 99
#
# 737  :  True 99 77
#  True
# 87 21 99 77
#
# 738  :  True 98 97
#  True
# 12 13 98 97
#
# 739  :  False 79 79
#  True
# 14 2 79 79
#
# 740  :  False 2 3
#  True
# 2 2 2 3
#
# 741  :  False 73 74
#  True
# 38 73 73 74
#
# 742  :  True 82 7
#  True
# 11 4 82 7
#
# 743  :  False 67 71
#  True
# 67 68 67 71
#
# 744  :  True 87 84
#  True
# 86 13 87 84
#
# 745  :  True 80 52
#  True
# 52 51 80 52
#
# 746  :  True 97 96
#  True
# 71 71 97 96
#
# 747  :  False 5 87
#  True
# 4 5 5 87
#
# 748  :  False 31 73
#  True
# 14 31 31 73
#
# 749  :  False 28 55
#  True
# 28 27 28 55
#
# 750  :  True 3 28
#  True
# 3 2 3 28
#
# 751  :  False 67 73
#  True
# 37 65 67 73
#
# 752  :  True 80 79
#  True
# 79 73 80 79
#
# 753  :  True 95 94
#  True
# 16 17 95 94
#
# 754  :  True 77 76
#  True
# 7 8 77 76
#
# 755  :  False 82 82
#  True
# 16 18 82 82
#
# 756  :  False 34 93
#  True
# 34 33 34 93
#
# 757  :  False 84 88
#  True
# 13 88 84 88
#
# 758  :  True 98 97
#  True
# 37 9 98 97
#
# 759  :  False 40 59
#  True
# 16 7 40 59
#
# 760  :  True 96 3
#  True
# 3 1 96 3
#
# 761  :  False 95 99
#  True
# 3 30 95 99
#
# 762  :  False 84 85
#  True
# 1 2 84 85
#
# 763  :  False 3 56
#  True
# 2 4 3 56
#
# 764  :  False 54 55
#  True
# 5 6 54 55
#
# 765  :  False 93 93
#  True
# 69 36 93 93
#
# 766  :  True 89 88
#  True
# 31 44 89 88
#
# 767  :  True 88 87
#  True
# 5 23 88 87
#
# 768  :  False 87 88
#  True
# 5 4 87 88
#
# 769  :  True 90 84
#  True
# 85 42 90 84
#
# 770  :  True 72 37
#  True
# 44 33 72 37
#
# 771  :  False 11 99
#  True
# 7 21 11 99
#
# 772  :  False 91 91
#  True
# 32 31 91 91
#
# 773  :  False 99 99
#  True
# 99 61 99 99
#
# 774  :  True 79 44
#  True
# 5 10 79 44
#
# 775  :  True 94 84
#  True
# 59 58 94 84
#
# 776  :  False 6 99
#  True
# 4 5 6 99
#
# 777  :  False 29 82
#  True
# 24 28 29 82
#
# 778  :  True 41 40
#  True
# 23 23 41 40
#
# 779  :  False 95 96
#  True
# 6 95 95 96
#
# 780  :  True 99 53
#  True
# 18 17 99 53
#
# 781  :  True 95 85
#  True
# 87 32 95 85
#
# 782  :  False 66 67
#  True
# 28 28 66 67
#
# 783  :  False 94 99
#  True
# 4 99 94 99
#
# 784  :  False 97 98
#  True
# 22 22 97 98
#
# 785  :  True 96 31
#  True
# 30 14 96 31
#
# 786  :  True 70 69
#  True
# 30 31 70 69
#
# 787  :  False 74 89
#  True
# 56 3 74 89
#
# 788  :  False 85 86
#  True
# 4 86 85 86
#
# 789  :  False 97 97
#  True
# 57 58 97 97
#
# 790  :  False 95 96
#  True
# 41 41 95 96
#
# 791  :  True 79 78
#  True
# 78 37 79 78
#
# 792  :  False 70 75
#  True
# 25 70 70 75
#
# 793  :  False 92 93
#  True
# 92 4 92 93
#
# 794  :  False 65 73
#  True
# 46 66 65 73
#
# 795  :  False 20 23
#  True
# 18 19 20 23
#
# 796  :  True 90 89
#  True
# 32 32 90 89
#
# 797  :  False 73 95
#  True
# 38 38 73 95
#
# 798  :  True 69 68
#  True
# 30 31 69 68
#
# 799  :  False 68 78
#  True
# 49 1 68 78
#
# 800  :  True 98 97
#  True
# 18 10 98 97
#
# 801  :  True 65 22
#  True
# 25 14 65 22
#
# 802  :  True 46 45
#  True
# 14 12 46 45
#
# 803  :  True 48 32
#  True
# 19 20 48 32
#
# 804  :  True 83 52
#  True
# 52 29 83 52
#
# 805  :  True 95 94
#  True
# 57 57 95 94
#
# 806  :  True 97 96
#  True
# 4 4 97 96
#
# 807  :  False 91 92
#  True
# 35 90 91 92
#
# 808  :  False 99 99
#  True
# 5 4 99 99
#
# 809  :  False 26 27
#  True
# 4 4 26 27
#
# 810  :  True 73 54
#  True
# 54 6 73 54
#
# 811  :  False 98 99
#  True
# 6 7 98 99
#
# 812  :  True 81 80
#  True
# 63 7 81 80
#
# 813  :  True 85 59
#  True
# 58 59 85 59
#
# 814  :  False 2 88
#  True
# 1 1 2 88
#
# 815  :  False 85 93
#  True
# 71 51 85 93
#
# 816  :  True 65 6
#  True
# 5 6 65 6
#
# 817  :  False 49 93
#  True
# 3 33 49 93
#
# 818  :  False 84 84
#  True
# 44 5 84 84
#
# 819  :  True 62 61
#  True
# 49 48 62 61
#
# 820  :  False 98 99
#  True
# 35 36 98 99
#
# 821  :  False 3 64
#  True
# 2 10 3 64
#
# 822  :  False 95 95
#  True
# 95 43 95 95
#
# 823  :  False 55 56
#  True
# 2 3 55 56
#
# 824  :  True 53 52
#  True
# 20 20 53 52
#
# 825  :  True 97 13
#  True
# 15 11 97 13
#
# 826  :  False 81 81
#  True
# 81 3 81 81
#
# 827  :  True 45 44
#  True
# 40 1 45 44
#
# 828  :  False 3 73
#  True
# 1 5 3 73
#
# 829  :  False 97 98
#  True
# 4 97 97 98
#
# 830  :  True 92 91
#  True
# 91 12 92 91
#
# 831  :  True 64 63
#  True
# 31 30 64 63
#
# 832  :  True 55 54
#  True
# 18 17 55 54
#
# 833  :  True 40 35
#  True
# 35 34 40 35
#
# 834  :  False 6 95
#  True
# 3 5 6 95
#
# 835  :  False 70 94
#  True
# 26 79 70 94
#
# 836  :  False 97 97
#  True
# 4 8 97 97
#
# 837  :  False 63 63
#  True
# 6 28 63 63
#
# 838  :  True 95 21
#  True
# 28 11 95 21
#
# 839  :  True 81 6
#  True
# 5 1 81 6
#
# 840  :  True 41 40
#  True
# 38 39 41 40
#
# 841  :  True 96 88
#  True
# 49 48 96 88
#
# 842  :  False 77 77
#  True
# 59 58 77 77
#
# 843  :  False 40 40
#  True
# 29 28 40 40
#
# 844  :  True 75 46
#  True
# 45 46 75 46
#
# 845  :  True 87 67
#  True
# 3 4 87 67
#
# 846  :  True 99 92
#  True
# 58 4 99 92
#
# 847  :  True 57 47
#  True
# 47 46 57 47
#
# 848  :  True 84 80
#  True
# 24 15 84 80
#
# 849  :  True 92 85
#  True
# 85 38 92 85
#
# 850  :  False 89 90
#  True
# 55 88 89 90
#
# 851  :  True 68 67
#  True
# 32 67 68 67
#
# 852  :  False 89 89
#  True
# 7 8 89 89
#
# 853  :  False 92 92
#  True
# 14 13 92 92
#
# 854  :  False 41 41
#  True
# 29 30 41 41
#
# 855  :  False 92 92
#  True
# 5 4 92 92
#
# 856  :  False 29 41
#  True
# 9 19 29 41
#
# 857  :  False 89 99
#  True
# 65 90 89 99
#
# 858  :  False 91 91
#  True
# 91 60 91 91
#
# 859  :  True 70 68
#  True
# 5 21 70 68
#
# 860  :  True 95 92
#  True
# 11 35 95 92
#
# 861  :  True 65 26
#  True
# 25 14 65 26
#
# 862  :  False 93 94
#  True
# 52 88 93 94
#
# 863  :  False 89 90
#  True
# 52 51 89 90
#
# 864  :  True 87 86
#  True
# 74 86 87 86
#
# 865  :  False 96 99
#  True
# 32 99 96 99
#
# 866  :  True 97 6
#  True
# 5 4 97 6
#
# 867  :  False 91 91
#  True
# 19 20 91 91
#
# 868  :  False 76 77
#  True
# 65 64 76 77
#
# 869  :  False 90 90
#  True
# 36 37 90 90
#
# 870  :  False 82 92
#  True
# 37 25 82 92
#
# 871  :  False 78 84
#  True
# 76 77 78 84
#
# 872  :  False 66 66
#  True
# 5 5 66 66
#
# 873  :  True 9 50
#  True
# 4 12 9 50
#
# 874  :  False 52 52
#  True
# 2 10 52 52
#
# 875  :  True 99 98
#  True
# 15 14 99 98
#
# 876  :  True 96 18
#  True
# 18 6 96 18
#
# 877  :  True 81 33
#  True
# 3 4 81 33
#
# 878  :  False 66 71
#  True
# 21 15 66 71
#
# 879  :  False 49 67
#  True
# 49 27 49 67
#
# 880  :  False 4 94
#  True
# 4 5 4 94
#
# 881  :  False 50 51
#  True
# 50 9 50 51
#
# 882  :  True 95 94
#  True
# 31 30 95 94
#
# 883  :  False 91 93
#  True
# 82 87 91 93
#
# 884  :  True 96 95
#  True
# 61 17 96 95
#
# 885  :  False 95 95
#  True
# 2 17 95 95
#
# 886  :  True 37 35
#  True
# 34 7 37 35
#
# 887  :  True 94 85
#  True
# 2 7 94 85
#
# 888  :  True 96 95
#  True
# 96 49 96 95
#
# 889  :  False 41 59
#  True
# 41 42 41 59
#
# 890  :  False 97 97
#  True
# 2 3 97 97
#
# 891  :  False 97 98
#  True
# 22 22 97 98
#
# 892  :  True 95 82
#  True
# 33 34 95 82
#
# 893  :  False 47 72
#  True
# 33 47 47 72
#
# 894  :  False 93 93
#  True
# 32 33 93 93
#
# 895  :  True 58 35
#  True
# 36 35 58 35
#
# 896  :  False 58 58
#  True
# 10 52 58 58
#
# 897  :  True 89 67
#  True
# 77 60 89 67
#
# 898  :  False 13 81
#  True
# 3 12 13 81
#
# 899  :  False 98 98
#  True
# 14 40 98 98
#
# 900  :  True 94 12
#  True
# 11 7 94 12
#
# 901  :  False 63 63
#  True
# 51 43 63 63
#
# 902  :  True 82 81
#  True
# 22 2 82 81
#
# 903  :  False 34 60
#  True
# 31 35 34 60
#
# 904  :  True 79 42
#  True
# 8 8 79 42
#
# 905  :  False 67 88
#  True
# 67 66 67 88
#
# 906  :  True 81 64
#  True
# 64 4 81 64
#
# 907  :  False 96 97
#  True
# 16 15 96 97
#
# 908  :  False 65 65
#  True
# 22 23 65 65
#
# 909  :  True 97 96
#  True
# 59 60 97 96
#
# 910  :  False 89 99
#  True
# 18 90 89 99
#
# 911  :  False 2 97
#  True
# 2 3 2 97
#
# 912  :  False 63 63
#  True
# 12 11 63 63
#
# 913  :  False 42 59
#  True
# 12 41 42 59
#
# 914  :  True 37 36
#  True
# 36 31 37 36
#
# 915  :  True 91 59
#  True
# 45 2 91 59
#
# 916  :  True 89 8
#  True
# 7 6 89 8
#
# 917  :  False 49 50
#  True
# 21 21 49 50
#
# 918  :  False 13 87
#  True
# 13 12 13 87
#
# 919  :  False 89 90
#  True
# 48 47 89 90
#
# 920  :  False 22 55
#  True
# 3 2 22 55
#
# 921  :  False 19 41
#  True
# 19 20 19 41
#
# 922  :  False 67 94
#  True
# 48 47 67 94
#
# 923  :  False 13 83
#  True
# 11 12 13 83
#
# 924  :  True 62 61
#  True
# 16 16 62 61
#
# 925  :  False 35 41
#  True
# 11 12 35 41
#
# 926  :  True 78 71
#  True
# 71 5 78 71
#
# 927  :  False 67 87
#  True
# 66 67 67 87
#
# 928  :  False 71 71
#  True
# 22 14 71 71
#
# 929  :  False 72 72
#  True
# 19 15 72 72
#
# 930  :  True 42 41
#  True
# 20 21 42 41
#
# 931  :  True 94 93
#  True
# 8 7 94 93
#
# 932  :  True 98 96
#  True
# 97 19 98 96
#
# 933  :  False 98 98
#  True
# 3 2 98 98
#
# 934  :  False 71 73
#  True
# 33 72 71 73
#
# 935  :  False 35 81
#  True
# 33 34 35 81
#
# 936  :  True 98 97
#  True
# 18 18 98 97
#
# 937  :  False 85 86
#  True
# 85 24 85 86
#
# 938  :  True 97 96
#  True
# 7 26 97 96
#
# 939  :  False 47 49
#  True
# 47 46 47 49
#
# 940  :  False 14 3
#  True
# 5 3 14 3
# 941  :  False 83 83
#  True
# 1 14 83 83
#
# 942  :  True 91 75
#  True
# 10 3 91 75
#
# 943  :  False 62 63
#  True
# 62 32 62 63
#
# 944  :  False 84 84
#  True
# 16 83 84 84
#
# 945  :  False 53 70
#  True
# 52 52 53 70
#
# 946  :  False 47 47
#  True
# 2 2 47 47
#
# 947  :  True 93 24
#  True
# 8 8 93 24
#
# 948  :  False 97 97
#  True
# 56 97 97 97
#
# 949  :  False 84 84
#  True
# 8 27 84 84
#
# 950  :  False 89 89
#  True
# 71 89 89 89
#
# 951  :  True 98 96
#  True
# 96 30 98 96
#
# 952  :  False 92 92
#  True
# 11 49 92 92
#
# 953  :  False 66 67
#  True
# 66 19 66 67
#
# 954  :  True 57 56
#  True
# 55 54 57 56
#
# 955  :  False 69 70
#  True
# 3 3 69 70
#
# 956  :  True 99 6
#  True
# 5 4 99 6
#
# 957  :  True 40 39
#  True
# 1 1 40 39
#
# 958  :  False 87 89
#  True
# 1 88 87 89
#
# 959  :  True 98 96
#  True
# 11 20 98 96
#
# 960  :  False 92 94
#  True
# 22 21 92 94
#
# 961  :  True 88 86
#  True
# 5 5 88 86
#
# 962  :  True 98 97
#  True
# 79 79 98 97
#
# 963  :  False 88 88
#  True
# 34 82 88 88
#
# 964  :  True 80 79
#  True
# 67 66 80 79
#
# 965  :  True 87 17
#  True
# 16 9 87 17
#
# 966  :  False 91 92
#  True
# 78 92 91 92
#
# 967  :  False 57 57
#  True
# 46 35 57 57
#
# 968  :  True 64 44
#  True
# 45 44 64 44
#
# 969  :  True 82 81
#  True
# 77 12 82 81
#
# 970  :  True 98 3
#  True
# 3 1 98 3
#
# 971  :  False 62 89
#  True
# 42 62 62 89
#
# 972  :  False 70 95
#  True
# 2 95 70 95
#
# 973  :  False 63 63
#  True
# 62 61 63 63
#
# 974  :  False 97 98
#  True
# 39 38 97 98
#
# 975  :  True 99 98
#  True
# 3 6 99 98
#
# 976  :  True 84 83
#  True
# 26 83 84 83
#
# 977  :  False 27 28
#  True
# 18 17 27 28
#
# 978  :  True 58 52
#  True
# 52 7 58 52
#
# 979  :  False 82 82
#  True
# 25 1 82 82
#
# 980  :  False 66 67
#  True
# 29 67 66 67
#
# 981  :  True 72 71
#  True
# 43 21 72 71
#
# 982  :  True 29 28
#  True
# 23 5 29 28
#
# 983  :  True 90 44
#  True
# 43 43 90 44
#
# 984  :  True 68 67
#  True
# 42 42 68 67
#
# 985  :  False 69 70
#  True
# 67 66 69 70
#
# 986  :  False 40 57
#  True
# 19 18 40 57
#
# 987  :  False 1 9
#  True
# 1 8 1 9
#
# 988  :  False 89 99
#  True
# 56 97 89 99
#
# 989  :  True 98 86
#  True
# 87 25 98 86
#
# 990  :  True 98 88
#  True
# 88 10 98 88
#
# 991  :  False 93 96
#  True
# 2 2 93 96
#
# 992  :  False 82 89
#  True
# 3 82 82 89
#
# 993  :  False 14 14
#  True
# 7 8 14 14
#
# 994  :  False 37 56
#  True
# 3 36 37 56
#
# 995  :  True 52 51
#  True
# 51 4 52 51
#
# 996  :  False 88 96
#  True
# 38 37 88 96
#
# 997  :  False 81 81
#  True
# 74 22 81 81
#
# 998  :  True 83 70
#  True
# 69 68 83 70
#
# 999  :  False 91 91
#  True
# 2 38 91 91
#
# 1000  :  False 90 96
#  True
# 2 91 90 96
#
# 475

# %%
text = open("input4.txt","r")
lines = text.readlines()
score = 0

for compteur, line in enumerate(lines):
    elf1, elf2 = line.split(",")
    inter_1 = elf1.split("-")
    inter_2 = elf2.split("-")
    bool1 = (int(inter_1[1]) >= int(inter_2[0]) and int(inter_1[1]) <= int(inter_2[1]))
    bool2 = (int(inter_2[1]) >= int(inter_1[0])) and (int(inter_2[1]) <= int(inter_1[1]))
    if bool1 or bool2:
        score += 1

print(score)
# Out:
# 825

# %% [markdown]
# Jour 5

# %%
text = open("input5.txt","r")
lines = text.readlines()
i = 0
stacks = [[],[],[],[],[],[],[],[],[]]
lines_init = lines[:8]

for i in reversed(range(8)):
    for j in range(9):
        if not str(lines_init[i][int(1+j*4)]) == " ":
            stacks[j].append(lines_init[i][int(1+j*4)])

lines_move = lines[10:]

for line in lines_move:
    content = line.split()
    for i in range(int(content[1])):
        letter = stacks[int(content[3])-1].pop()
        stacks[int(content[5])-1].append(letter)
        
print(stacks)

score = ""
for k in range(9):
    letter = stacks[k].pop()
    score += letter
    
print(score)
# Out:
# [['J'], ['L', 'R'], ['V'], ['P', 'S', 'N'], ['N', 'B', 'S', 'H'], ['L', 'N', 'D', 'R', 'H', 'D', 'L', 'S', 'G', 'J', 'R', 'W', 'V', 'J', 'G', 'H', 'D', 'G', 'C', 'Q', 'H'], ['V', 'D', 'C', 'R', 'S', 'G', 'W', 'F', 'V', 'Z', 'N', 'M', 'R', 'B', 'G', 'B', 'M', 'F', 'F', 'H', 'J', 'C'], ['S'], ['J']]
# JRVNHHCSJ

# %%
text = open("input5.txt","r")
lines = text.readlines()
i = 0
stacks = [[],[],[],[],[],[],[],[],[]]
lines_init = lines[:8]

for i in reversed(range(8)):
    for j in range(9):
        if not str(lines_init[i][int(1+j*4)]) == " ":
            stacks[j].append(lines_init[i][int(1+j*4)])

lines_move = lines[10:]
tmp = []
for line in lines_move:
    content = line.split()
    tmp.clear()
    for i in range(int(content[1])):
        letter = stacks[int(content[3])-1].pop()
        tmp.append(letter)
    #tmp = list(reversed(tmp))
    for j in range(len(tmp)):
        letter = tmp.pop()
        stacks[int(content[5])-1].append(letter)
        
print(stacks)

score = ""
for k in range(9):
    letter = stacks[k].pop()
    score += letter
    
print(score)
# Out:
# [['G'], ['J', 'N'], ['F'], ['J', 'V', 'B'], ['V', 'G', 'V', 'S'], ['R', 'D', 'N', 'S', 'H', 'D', 'Z', 'N', 'R', 'D', 'W', 'S', 'H', 'B', 'C', 'S', 'D', 'R', 'L', 'P', 'B'], ['M', 'M', 'R', 'G', 'C', 'H', 'G', 'J', 'L', 'R', 'C', 'F', 'S', 'F', 'G', 'V', 'W', 'N', 'J', 'H', 'Q', 'J'], ['L'], ['H']]
# GNFBSBJLH

# %% [markdown]
# Jour 6

# %%
import numpy as np
text = open("input6.txt","r")
buffer = text.readlines()
mark = []
for score, letter in enumerate(buffer[0]):
    if len(mark) < 14:
        mark.append(ord(letter))
    else:
        mark_array = np.array(mark)
        if np.unique(mark_array).size == 14:
            print(mark)
            break
        else:
            mark = mark[1:]
            mark.append(ord(letter))
        
print(score)
# Out:
# [103, 106, 115, 109, 112, 116, 122, 98, 99, 108, 102, 100, 110, 119]
# 3697

# %% [markdown]
# Jour 7

# %%
text = open("input7.txt","r")
lines = text.readlines()

#Construction de l'arborescence
father = {}
contains = {}
currentDirectory = ""
for line in lines:
    if line[0] == "$":
        if line[2:4] == "cd":
            match line[5:-1]:
                case "..":
                    currentDirectory = father[currentDirectory]
                case "/":
                    currentDirectory = "/"
                    contains[currentDirectory] = []
                case _:
                    father[line[5:-1]] = currentDirectory
                    if not currentDirectory in contains.keys():
                        contains[currentDirectory] = []
                    else:
                        if not "dir "+line[5:-1] in contains.values():
                            contains[currentDirectory].append("dir "+line[5:-1])
                    currentDirectory = line[5:-1]
                    contains[currentDirectory] = []

    else:
        if not line in contains[currentDirectory]:
            contains[currentDirectory].append(line[:-1])

#Calcul de la taille des fichiers
size_dirs = {}
def size_dir(directory):
    size_dirs[directory] = 0
    for line in contains[directory]:
        if line[:3] == "dir":
            size_dir(line[4:])
            size_dirs[directory] += size_dirs[line[4:]]
        else:
            size_dirs[directory] += int(line.split()[0])
    
            
size_dir("/")
score = 0
for size in size_dirs.values():
    if size <= 100000:
        score += size
        
print(score)
print(len(size_dirs.keys()))
print(len(contains.keys()))

contains
# Out:
# 452580
# 65
# 131
# {'/': ['dir plws',
#   'dir pwlbgbz',
#   'dir pwtpltr',
#   'dir szn',
#   'dir plws',
#   'dir pwlbgbz'],
#  'plws': ['dir ffpzc',
#   'dir frcmjzts',
#   '92461 nbvnzg',
#   'dir phqcg',
#   '21621 vqgsglwq',
#   'dir ffpzc',
#   'dir frcmjzts',
#   'dir phqcg'],
#  'ffpzc': ['dir snjntth', 'dir snjntth'],
#  'frcmjzts': ['dir bsltmjz', 'dir jfzgrbm', 'dir bsltmjz', 'dir jfzgrbm'],
#  'bsltmjz': ['14981 pqzffzjc'],
#  'jfzgrbm': ['132811 fcmpng',
#   '103661 lgt.swt',
#   '173031 vqgsglwq',
#   '29134 wprjfg.zbr'],
#  'phqcg': ['955 jgfs.zjw'],
#  'pwlbgbz': ['dir gbg',
#   'dir mjzhcwrd',
#   'dir njcscpj',
#   'dir sphbzn',
#   'dir tbgjpphc',
#   '55938 tvrfpczc.djm',
#   '4840 twd',
#   'dir gbg',
#   'dir mjzhcwrd',
#   'dir njcscpj',
#   'dir sphbzn'],
#  'gbg': ['287003 fcsjl.bzm', 'dir wgq', 'dir wgq'],
#  'wgq': ['22963 fcsjl.fcm'],
#  'mjzhcwrd': ['228632 clfnpmbq.zmb', '28276 dzdfc.vqq', '2982 tdbg.wgn'],
#  'njcscpj': ['dir dqzgqgv',
#   '275186 ffpzc',
#   '192491 gjnflc.plq',
#   'dir dqzgqgv'],
#  'dqzgqgv': ['70309 dzdfc.vqq',
#   '56139 fcsjl',
#   '142095 sgwz.cdz',
#   'dir snjntth',
#   'dir sphbzn',
#   '284618 wjlmgq',
#   'dir snjntth',
#   'dir sphbzn'],
#  'snjntth': ['86775 dzdfc.vqq', '19560 vshcmjj'],
#  'vrfgfds': ['155233 jlscz'],
#  'sphbzn': ['20140 fcsjl.zrs',
#   '260579 snjntth',
#   'dir tbqphzb',
#   'dir vdcqgts',
#   'dir qhjv',
#   'dir snjntth'],
#  'qbzwrrw': ['278531 fcsjl.tqj', '211591 snjntth.gpd'],
#  'qwpzn': ['174183 vqgsglwq'],
#  'bsvh': ['130814 wjlmgq'],
#  'fvzcs': ['dir cgmv',
#   'dir ggzwljr',
#   '298241 qvzghdpw.lms',
#   'dir snjntth',
#   'dir sphbzn',
#   'dir cgmv',
#   'dir ggzwljr',
#   'dir snjntth'],
#  'cgmv': ['46843 dzdfc.vqq',
#   'dir lmqcbbm',
#   'dir rstcqsmd',
#   '215261 snjntth',
#   'dir lmqcbbm',
#   'dir rstcqsmd'],
#  'lmqcbbm': ['229898 bdmbvgp', '25529 ffpzc.stm', '16871 lnpjzvg.qlj'],
#  'rstcqsmd': ['289038 zrbbbwng.smf'],
#  'ggzwljr': ['198200 bcthn'],
#  'pggcwb': ['154272 fqztwvnv.lvv',
#   'dir pdjg',
#   '62393 vqgsglwq',
#   'dir wjhrtg',
#   'dir pdjg',
#   'dir wjhrtg'],
#  'pdjg': ['260644 gvhlrcf', '209906 wpls.pbd'],
#  'wjhrtg': ['148640 dljf.zrq',
#   '172168 dzdfc.vqq',
#   '196203 hjdphcfm',
#   '247620 sgwz.cdz'],
#  'bsqqdr': ['117496 wcqt'],
#  'frsmrd': ['111509 sphbzn.shz'],
#  'ndw': ['241303 bht.rpj', '173068 vqgsglwq'],
#  'nlml': ['228982 hzglfpvq.ftt', '114981 sgwz.cdz'],
#  'pcbt': ['dir bsltmjz',
#   'dir ffpzc',
#   'dir fjsjwfg',
#   'dir fwm',
#   'dir jvwt',
#   '227943 tmr.jdc',
#   'dir vwpqzdwh',
#   '31258 wjlmgq',
#   'dir bsltmjz',
#   'dir ffpzc',
#   'dir fjsjwfg'],
#  'flrpwfs': ['60566 wvjq.gmm'],
#  'fjsjwfg': ['152232 dnsdd.jgz',
#   '181301 gsb.wsh',
#   'dir jqpb',
#   'dir jscbg',
#   'dir snjntth',
#   '227677 snjntth.vvg',
#   'dir sphbzn',
#   '75358 vqgsglwq',
#   '2589 wjlmgq',
#   'dir jqpb',
#   'dir jscbg',
#   'dir snjntth'],
#  'jqpb': ['253403 mmnvqn.hqb', '108325 rvq.mrc'],
#  'jscbg': ['dir dtm',
#   'dir gsdnz',
#   '208269 prh',
#   '25977 qdzljgh',
#   '169262 vmnq.mth',
#   'dir dtm',
#   'dir gsdnz'],
#  'dtm': ['80072 gzqnb'],
#  'gsdnz': ['dir dsqzjs', '297895 sgwz.cdz', '129983 vqgsglwq', 'dir dsqzjs'],
#  'dsqzjs': ['2621 jqrlsf.gzs', '164844 snjntth'],
#  'lmn': ['46401 bsltmjz', '96888 shrnqhvq'],
#  'ctj': ['82485 fcsjl.lfl'],
#  'vlnfhbq': ['250106 qvf'],
#  'wpwl': ['153950 cmsd.rlg'],
#  'glgq': ['285182 wjlmgq'],
#  'fwm': ['251865 ffpzc.qgb', '279522 zvvpfqtp'],
#  'jvwt': ['48990 bsltmjz.nzp', '219604 ffpzc', '69573 mvmdfzr.lwb'],
#  'vwpqzdwh': ['267581 pvcch'],
#  'tbgjpphc': ['255571 dstpcgr.tfq',
#   'dir fdbwbrpp',
#   'dir gjzwh',
#   'dir hjvrtjt',
#   'dir rhzczj',
#   '292888 sgwz.cdz',
#   'dir wlzhr',
#   '149395 wnfzrqgz.dtn',
#   'dir fdbwbrpp',
#   'dir gjzwh',
#   'dir hjvrtjt',
#   'dir rhzczj',
#   'dir wlzhr'],
#  'fdbwbrpp': ['dir ffpzc',
#   'dir qbrth',
#   '51164 qprp',
#   'dir slpt',
#   '117026 sphbzn',
#   '295685 vqgsglwq',
#   'dir znmj',
#   'dir ffpzc',
#   'dir qbrth',
#   'dir slpt',
#   'dir znmj'],
#  'jhnzrdvb': ['217775 ffpzc.sgw'],
#  'qbrth': ['183969 lpbwgfjv.vcg', '47333 wjlmgq'],
#  'slpt': ['32343 tqhtj.jwz'],
#  'znmj': ['55058 mmnvqn.hqb'],
#  'gjzwh': ['dir dvcbcd',
#   '202530 dzdfc.vqq',
#   'dir fsgz',
#   'dir hfrrqq',
#   '54897 jlzn.qsn',
#   '16097 ldzqsbb.jzl',
#   '225078 pswccrd',
#   'dir rqqmldw',
#   '292464 rzrdhbp.vld',
#   'dir ssqbqqp',
#   'dir zsztqrc',
#   'dir dvcbcd',
#   'dir fsgz',
#   'dir hfrrqq',
#   'dir rqqmldw',
#   'dir ssqbqqp',
#   'dir zsztqrc'],
#  'dvcbcd': ['187837 dzdfc.vqq',
#   'dir jlwtvf',
#   'dir jnjvshs',
#   '164053 nrf.fqd',
#   '5665 tlp.jmt',
#   '13801 wjlmgq',
#   'dir jlwtvf',
#   'dir jnjvshs'],
#  'jlwtvf': ['219985 sphbzn.dvj'],
#  'jnjvshs': ['dir bsltmjz', 'dir nrpm', 'dir bsltmjz', 'dir nrpm'],
#  'nrpm': ['18509 wjlmgq'],
#  'fsgz': ['224576 mmnvqn.hqb'],
#  'hfrrqq': ['dir bwgsnfvb',
#   'dir fcsjl',
#   '294608 ffpzc.gvm',
#   '136880 qjcgtw',
#   'dir sphbzn',
#   'dir bwgsnfvb',
#   'dir fcsjl',
#   'dir sphbzn'],
#  'bwgsnfvb': ['29735 dzdfc.vqq', 'dir wstmzfml', 'dir wstmzfml'],
#  'wstmzfml': ['158447 bnvhbvvc.nrt', '59889 jclclgd'],
#  'fcsjl': ['276802 fcsjl.psm', '197934 sgwz.cdz'],
#  'wqdths': ['8326 cgvtw.jpz'],
#  'rqqmldw': ['226757 dzdfc.vqq',
#   '115055 mwb.btc',
#   'dir qpts',
#   '298524 sgwz.cdz',
#   'dir qpts'],
#  'qpts': ['60860 bsltmjz.frp',
#   'dir fcsjl',
#   '94904 sgwz.cdz',
#   'dir wnmqqspz',
#   'dir fcsjl',
#   'dir wnmqqspz'],
#  'wnmqqspz': ['165529 sgwz.cdz'],
#  'ssqbqqp': ['192477 pvrgm'],
#  'zsztqrc': ['254053 lht.htn'],
#  'hjvrtjt': ['189942 fwps'],
#  'rhzczj': ['36502 bmtfr',
#   'dir ffjz',
#   '35148 nctfhmzm.vsz',
#   'dir qdgjzcz',
#   '208196 rwql',
#   '79863 sgwz.cdz',
#   'dir snjntth',
#   'dir ffjz',
#   'dir qdgjzcz',
#   'dir snjntth',
#   'dir pwtpltr'],
#  'ffjz': ['dir grsvhwm', 'dir grsvhwm'],
#  'grsvhwm': ['50231 fwj.rdv', 'dir snjntth', 'dir snjntth'],
#  'dtbgb': ['150245 vdflm.lmq'],
#  'qdgjzcz': ['222389 dzdfc.vqq'],
#  'wlzhr': ['116628 bsltmjz',
#   '60122 jqpbsgnr.fgb',
#   '252605 lfss',
#   '300065 qwjdl.vhr'],
#  'pwtpltr': ['dir dplsvrhl',
#   '140951 gwtfzqvd.znb',
#   'dir jbvdb',
#   'dir jst',
#   'dir qhjv',
#   'dir snjntth',
#   'dir dplsvrhl',
#   'dir jbvdb',
#   'dir jst'],
#  'dplsvrhl': ['272101 fcsjl',
#   'dir ffpzc',
#   '58852 mmnvqn.hqb',
#   'dir mnhntjz',
#   '91899 sgwz.cdz',
#   '228077 snjntth.btv',
#   'dir ffpzc',
#   'dir mnhntjz'],
#  'qmfwpjhl': ['300362 dzdfc.vqq'],
#  'rsrb': ['252983 dzdfc.vqq',
#   '107744 ltssrgqb.zvj',
#   '214895 rhglgcwr.wpw',
#   '249727 sgwz.cdz'],
#  'wgt': ['141984 dzdfc.vqq', '194686 mmnvqn.hqb', '258023 pgr'],
#  'mnhntjz': ['dir bdvght',
#   'dir jprwchh',
#   'dir snjntth',
#   'dir bdvght',
#   'dir jprwchh',
#   'dir snjntth'],
#  'bdvght': ['243166 vpsvjdq.wsn'],
#  'jprwchh': ['178943 bmpc.bjb'],
#  'nlbm': ['33050 fcsjl.rcc', 'dir sphbzn', '17446 wjlmgq', 'dir sphbzn'],
#  'zjmjntff': ['82134 sgwz.cdz', '52203 vrtlgdq.crp'],
#  'jbvdb': ['dir wmtjh', 'dir wmtjh'],
#  'wmtjh': ['dir ggvwn', 'dir ggvwn'],
#  'ggvwn': ['192285 spqvmf.sdh'],
#  'jst': ['dir bsltmjz',
#   '212740 dzdfc.vqq',
#   'dir gncztvtb',
#   'dir jsqjcqnt',
#   '286257 jvs',
#   '36654 sdcsm.mbg',
#   '192040 sgwz.cdz',
#   'dir tbqphzb',
#   'dir vdcqgts',
#   '285843 wjlmgq',
#   'dir bsltmjz',
#   'dir gncztvtb',
#   'dir jsqjcqnt'],
#  'gncztvtb': ['229298 vqgsglwq'],
#  'jsqjcqnt': ['dir bsltmjz',
#   'dir fcsjl',
#   'dir ffpzc',
#   'dir sphbzn',
#   '70864 vqgsglwq',
#   'dir bsltmjz',
#   'dir fcsjl',
#   'dir ffpzc',
#   'dir sphbzn'],
#  'psmtphhq': ['dir ffpzc', '123131 tzgwd', 'dir ffpzc'],
#  'gcnrp': ['283 vqnrgl.vwp'],
#  'llnztjf': ['63263 tjhm.bwh'],
#  'nbqs': ['dir vssmq', 'dir vssmq'],
#  'vssmq': ['88980 dzdfc.vqq'],
#  'tbqphzb': ['93470 sgwz.cdz'],
#  'vdcqgts': ['223564 dzdfc.vqq',
#   'dir ffpzc',
#   'dir gwhfgwf',
#   'dir nbjtqnng',
#   'dir snjntth',
#   'dir ffpzc',
#   'dir gwhfgwf',
#   'dir nbjtqnng',
#   'dir snjntth'],
#  'gwhfgwf': ['59918 jvfv.mpm', 'dir mjl', '211039 pcwl', 'dir mjl'],
#  'mjl': ['13004 pgjb.tpq', '195995 tms.fjz'],
#  'nbjtqnng': ['107058 dzdfc.vqq',
#   'dir ldrsd',
#   '111631 vqgsglwq',
#   '104599 wbzmdljw.tjq',
#   '155747 wjlmgq',
#   'dir ldrsd'],
#  'ldrsd': ['107439 jvjm'],
#  'qhjv': ['dir bmnm',
#   '68453 hjjpdgn.hwl',
#   'dir sjlbj',
#   'dir vqnrj',
#   'dir bmnm',
#   'dir sjlbj',
#   'dir vqnrj'],
#  'bmnm': ['1238 vqgsglwq'],
#  'sjlbj': ['44239 wzzbtmrz.gml'],
#  'vqnrj': ['3286 bsltmjz.qlc'],
#  'snmrdfbt': ['281025 bzrsds.lfg'],
#  'tcnmbcgg': ['194998 fcsjl',
#   'dir qdrmpqgn',
#   'dir rzqd',
#   'dir tcsds',
#   'dir qdrmpqgn',
#   'dir rzqd',
#   'dir tcsds'],
#  'qdrmpqgn': ['165713 qmzgt.tnc'],
#  'rzqd': ['dir cwhnmlv', '57819 fcsjl', '246864 pjnzdvd.gjm', 'dir cwhnmlv'],
#  'cwhnmlv': ['287539 mmnvqn.hqb', '215636 pbnjt.zbn', '124638 sqd'],
#  'tcsds': ['78812 gfmgb.wqj',
#   '218987 hnhfvz.dln',
#   '209640 mzzhqlq.zqp',
#   '102492 nml.ppg'],
#  'szn': ['dir fcsjl', 'dir snjntth', 'dir zjbp', 'dir fcsjl', 'dir snjntth'],
#  'lfb': ['dir btj',
#   '99591 dhrjbvvg.gwm',
#   '137224 dzdfc.vqq',
#   '201972 jtzmqsvj.wnd',
#   '9704 mmnvqn.hqb',
#   'dir pwg',
#   '200308 snjntth.css',
#   'dir wcmhcfm',
#   'dir zwhvmln',
#   'dir btj',
#   'dir pwg',
#   'dir wcmhcfm',
#   'dir zwhvmln'],
#  'btj': ['dir rnbzdfgn', '51799 wdhsm', 'dir wvf', 'dir rnbzdfgn', 'dir wvf'],
#  'rnbzdfgn': ['117095 bsltmjz.tlv'],
#  'wvf': ['dir ffpzc',
#   'dir ncbmgpsc',
#   'dir wtwrmjnt',
#   'dir ffpzc',
#   'dir ncbmgpsc',
#   'dir wtwrmjnt'],
#  'ncbmgpsc': ['147899 dzdfc.vqq'],
#  'wtwrmjnt': ['252366 pvpdv.jwz'],
#  'pwg': ['280845 fcsjl.fjz',
#   '44300 sgwz.cdz',
#   'dir snjntth',
#   '229605 vqgsglwq',
#   'dir snjntth'],
#  'wcmhcfm': ['229329 qsznhwlw.vjg'],
#  'zwhvmln': ['dir ffpzc',
#   'dir tjjzbf',
#   'dir wzcq',
#   'dir ffpzc',
#   'dir tjjzbf',
#   'dir wzcq'],
#  'ncnj': ['40920 htbjhjq'],
#  'tjjzbf': ['47522 mczn.spd'],
#  'wzcq': ['56662 ffpzc.vwp', 'dir snjntth', 'dir snjntth'],
#  'lrfcgzl': ['267485 rsjmpph.qqz'],
#  'zshh': ['dir ffpzc',
#   'dir gmn',
#   'dir snjntth',
#   '150048 tgtlh',
#   '32020 thfr',
#   '72152 vqgsglwq',
#   'dir ffpzc',
#   'dir gmn',
#   'dir snjntth',
#   'dir zjbp'],
#  'gmn': ['238996 sgwz.cdz'],
#  'zjbp': ['dir fcsjl',
#   '41522 nlvpb.fpf',
#   'dir nmtjtd',
#   'dir fcsjl',
#   'dir nmtjtd'],
#  'nmtjtd': ['47477 dvqmqlgw.ths', '51081 vqgsglwq']}

# %%
line = "$ cd plws"
line[5:]
# Out:
# 'plws'

# %%
for line in contains["/"]:
    print(line)
    print(line[4:])
# Out:
# dir plws
# plws
# dir pwlbgbz
# pwlbgbz
# dir pwtpltr
# pwtpltr
# dir szn
# szn
# dir plws
# plws
# dir pwlbgbz
# pwlbgbz
